# %%
import numpy as np 
import pandas as pd

# %%
date = pd.read_csv("orders.csv",)
time = pd.read_csv("messages.csv")

# %%
date.head()
# Out:
#          date  product_id  city_id  orders  Unnamed: 4
# 0  10-12-2019        5628       25       3         NaN
# 1  15-08-2018        3646       14     157         NaN
# 2  23-10-2018        1859       25       1         NaN
# 3  17-08-2019        7292       25       1         NaN
# 4  06-01-2019        4344       25       3         NaN

# %%
date.drop(['Unnamed: 4'],axis=1,inplace=True)
time.drop(['Unnamed: 2'],axis=1,inplace=True)

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  10-12-2019        5628       25       3
# 1  15-08-2018        3646       14     157
# 2  23-10-2018        1859       25       1
# 3  17-08-2019        7292       25       1
# 4  06-01-2019        4344       25       3

# %%
time.head()
# Out:
#                date                                                msg
# 0  15-12-2013 00:50                           ищу на сегодня мужика 37
# 1  29-04-2014 23:40   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  30-12-2012 00:21            Днепр.м 43 позн.с д/ж *.о 067.16.34.576
# 3  28-11-2014 00:31  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  26-10-2013 23:11      Зая я тебя никогда не обижу люблю тебя!) Даше

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# # Working with dates

# %%
# Converting to datetime datatype
date['date'] = pd.to_datetime(date['date'])
# Out:
# C:\Users\NIKUNJ KIKANI\AppData\Local\Temp\ipykernel_11028\2629650099.py:2: UserWarning: Parsing '15-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   date['date'] = pd.to_datetime(date['date'])
# C:\Users\NIKUNJ KIKANI\AppData\Local\Temp\ipykernel_11028\2629650099.py:2: UserWarning: Parsing '23-10-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   date['date'] = pd.to_datetime(date['date'])
# C:\Users\NIKUNJ KIKANI\AppData\Local\Temp\ipykernel_11028\2629650099.py:2: UserWarning: Parsing '17-08-2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   date['date'] = pd.to_datetime(date['date'])
# C:\Users\NIKUNJ KIKANI\AppData\Local\Temp\ipykernel_11028\2629650099.py:2: UserWarning: Parsing '23-08-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %% [markdown]
# # 1. Extract Year

# %%
date['date_year'] = date['date'].dt.year

date.head()
# Out:
#         date  product_id  city_id  orders  date_year
# 0 2019-10-12        5628       25       3       2019
# 1 2018-08-15        3646       14     157       2018
# 2 2018-10-23        1859       25       1       2018
# 3 2019-08-17        7292       25       1       2019
# 4 2019-06-01        4344       25       3       2019

# %% [markdown]
# # 2. Extract Month

# %%
date['date_month'] = date['date'].dt.month_name()

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year date_month
# 0 2019-10-12        5628       25       3       2019    October
# 1 2018-08-15        3646       14     157       2018     August
# 2 2018-10-23        1859       25       1       2018    October
# 3 2019-08-17        7292       25       1       2019     August
# 4 2019-06-01        4344       25       3       2019       June

# %% [markdown]
# # 3. extract Day

# %%
date['date_day'] = date['date'].dt.day

# %%
date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year date_month  date_day
# 704 2019-12-11         468        0       5       2019   December        11
# 4   2019-06-01        4344       25       3       2019       June         1
# 740 2019-05-08         709       16     220       2019        May         8
# 929 2019-07-12        6801        3       7       2019       July        12
# 194 2019-09-08           5       16       1       2019  September         8

# %%
# day-of-week - name 

date['date_dow_name'] = date['date'].dt.day_name()

date.drop(['product_id','city_id','orders'],axis=1,inplace=True)

# %%
date.head()
# Out:
#         date  date_year date_month  date_day date_dow_name
# 0 2019-10-12       2019    October        12      Saturday
# 1 2018-08-15       2018     August        15     Wednesday
# 2 2018-10-23       2018    October        23       Tuesday
# 3 2019-08-17       2019     August        17      Saturday
# 4 2019-06-01       2019       June         1      Saturday

# %%
# is weekend ? 

date['date_is_weekend'] = np.where(date['date_dow_name'].isin(['Sunday','Saturday']),1,0)

# %%
date['date_week'] = date['date'].dt.week
# Out:
# C:\Users\NIKUNJ KIKANI\AppData\Local\Temp\ipykernel_11028\3869037006.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   date['date_week'] = date['date'].dt.week

# %%
date.head()
# Out:
#         date  date_year date_month  date_day date_dow_name  date_is_weekend  \
# 0 2019-10-12       2019    October        12      Saturday                1
# 1 2018-08-15       2018     August        15     Wednesday                0
# 2 2018-10-23       2018    October        23       Tuesday                0
# 3 2019-08-17       2019     August        17      Saturday                1
# 4 2019-06-01       2019       June         1      Saturday                1
#
#    date_week
# 0         41
# 1         33
# 2         43
# 3         33
# 4         22

# %%
date['quarter'] = date['date'].dt.quarter

# %%
date.head()
# Out:
#         date  date_year date_month  date_day date_dow_name  date_is_weekend  \
# 0 2019-10-12       2019    October        12      Saturday                1
# 1 2018-08-15       2018     August        15     Wednesday                0
# 2 2018-10-23       2018    October        23       Tuesday                0
# 3 2019-08-17       2019     August        17      Saturday                1
# 4 2019-06-01       2019       June         1      Saturday                1
#
#    date_week  quarter
# 0         41        4
# 1         33        3
# 2         43        4
# 3         33        3
# 4         22        2

# %%
#Extract Semester

date['semester'] = np.where(date['quarter'].isin([1,2]), 1, 2)

# %%
date
# Out:
#           date  date_year date_month  date_day date_dow_name  date_is_weekend  \
# 0   2019-10-12       2019    October        12      Saturday                1
# 1   2018-08-15       2018     August        15     Wednesday                0
# 2   2018-10-23       2018    October        23       Tuesday                0
# 3   2019-08-17       2019     August        17      Saturday                1
# 4   2019-06-01       2019       June         1      Saturday                1
# ..         ...        ...        ...       ...           ...              ...
# 995 2018-08-10       2018     August        10        Friday                0
# 996 2018-06-12       2018       June        12       Tuesday                0
# 997 2019-07-05       2019       July         5        Friday                0
# 998 2019-03-03       2019      March         3        Sunday                1
# 999 2019-10-15       2019    October        15       Tuesday                0
#
# ...

# %% [markdown]
# # extract time elapsed between  dates.

# %%
import datetime

today = datetime.datetime.today()

today
# Out:
# datetime.datetime(2022, 6, 20, 12, 50, 5, 218751)

# %%
(today - date['date']).dt.days
# Out:
# 0       982
# 1      1405
# 2      1336
# 3      1038
# 4      1115
#        ...
# 995    1410
# 996    1469
# 997    1081
# 998    1205
# 999     979
# Name: date, Length: 1000, dtype: int64

# %%
# Months passed

np.round((today -date['date']) / np.timedelta64(1, 'M'),0)
# Out:
# 0      32.0
# 1      46.0
# 2      44.0
# 3      34.0
# 4      37.0
#        ...
# 995    46.0
# 996    48.0
# 997    36.0
# 998    40.0
# 999    32.0
# Name: date, Length: 1000, dtype: float64

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
time['date'] = pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time['hour'] = time['date'].dt.hour
time['minute'] = time['date'].dt.minute
time['second'] = time['date'].dt.second

# %%
time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00            Днепр.м 43 позн.с д/ж *.о 067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00      Зая я тебя никогда не обижу люблю тебя!) Даше
#
#    hour  minute  second
# 0     0      50       0
# 1    23      40       0
# 2     0      21       0
# 3     0      31       0
# 4    23      11       0

# %%
# Extract time part

time['time'] = time['date'].dt.time

time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00            Днепр.м 43 позн.с д/ж *.о 067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00      Зая я тебя никогда не обижу люблю тебя!) Даше
#
#    hour  minute  second      time
# 0     0      50       0  00:50:00
# 1    23      40       0  23:40:00
# 2     0      21       0  00:21:00
# 3     0      31       0  00:31:00
# 4    23      11       0  23:11:00

# %%
# time differnce

# %%
today - time['date']
# Out:
# 0     3109 days 12:00:05.218751
# 1     2973 days 13:10:05.218751
# 2     3459 days 12:29:05.218751
# 3     2761 days 12:19:05.218751
# 4     3158 days 13:39:05.218751
#                  ...
# 995   3748 days 12:00:05.218751
# 996   3069 days 13:36:05.218751
# 997   3534 days 13:13:05.218751
# 998   3650 days 13:16:05.218751
# 999   2922 days 13:25:05.218751
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
# in scounds 

s = (today-time['date'])/np.timedelta64(1,'s')
m = (today-time['date'])/np.timedelta64(1,'m') # small (m) for minutes , capital (M) for months . 
h = (today-time['date'])/np.timedelta64(1,'h')

# %%
m
# Out:
# 0      4.477680e+06
# 1      4.281910e+06
# 2      4.981709e+06
# 3      3.976579e+06
# 4      4.548339e+06
#            ...
# 995    5.397840e+06
# 996    4.420176e+06
# 997    5.089753e+06
# 998    5.256796e+06
# 999    4.208485e+06
# Name: date, Length: 1000, dtype: float64
